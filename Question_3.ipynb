# %% [markdown]
# ![image.png](attachment:6a3bd2c0-5bc8-4d56-b8f6-1c1a4ca4868d.png)
# ![image.png](attachment:f62ecf57-8da6-4964-ae39-edea878bcd74.png)
#
# ### שאלה 1: ב
#
# ### שאלה 2: ג

# %% [markdown]
# ![image.png](attachment:1c1aba96-b667-4ecf-b20f-1a6173fe0cb5.png)
# ![image.png](attachment:3d04f921-cceb-4018-8e13-399d346a150b.png)
#
#
# ### שאלה 3: ב
#
# ### שאלה 4: ג

# %% [markdown]
# ![image.png](attachment:2875de13-8960-4689-9713-25e7347b2bd9.png)
# ![image.png](attachment:537786d4-cd7b-4984-b61d-ef380d81f5e5.png)
#
# ### שאלה 5: ג
#
# ### שאלה 6: ג

# %% [markdown]
# ![image.png](attachment:8ca4dd0f-2935-45ae-a5c4-7dac1718c31b.png)
# ![image.png](attachment:d645b637-4529-411a-8e2b-252a18513fab.png)
#
# ### שאלה 7: ד
#
# ### שאלה 8: ב

# %% [markdown]
# ![image.png](attachment:4c2c878b-a5f7-421e-b3fb-bb9a78228571.png)
# ![image.png](attachment:062cc98b-5d0f-4a43-9399-6f7510ab555e.png)
#
#
# ### שאלה 9: ג
#
# ### שאלה 10: א
